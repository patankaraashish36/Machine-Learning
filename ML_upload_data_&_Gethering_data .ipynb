# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # 1. CSV read via path (local read).

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv")
df
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore  2008-04-18     BB McCullum  \
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # 2. Read csv via URL

# %%
# import requests as r
# from io import stringIO
# url = "https://github.com/TheiScale/30_Days_Machine_Learning/blob/main/Day%203%20ML/IPL%20Matches%202008-2020.csv"
# # header = 
# req = r.get(url)
# data = stingIO(req.txt)
# pd.read_csv(data)

# %% [markdown]
# # 3. SEP parameter (TSV)

# %%
# For TSV file (If you get TSV file)

df = pd.read_csv("C:/Users/patan/Downloads/movie_titles_metadata.tsv", sep = "\t")
# df

# %% [markdown]
# #  4. Index_col parameter

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv" , index_col ="winner" )
# df

# %% [markdown]
# # 5. Header Parameter

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv", header = 1) 
#  Create first row header (convert first row into header )
# df

# %% [markdown]
# # 6. use_col Parameter (get only specific columns)

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv", usecols = ["player_of_match","winner","toss_winner","venue"])
# df

# %% [markdown]
# #  7. Squeeze parameters

# %%
# df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv" ,usecols= "winner", squeeze = True)

# %% [markdown]
# #  8. Skiprows/nrows Parameter

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv",skiprows = [0,1])
df
# skip 0 and 1 index row
# Out:
#       335983 Chandigarh  2008-04-19      MEK Hussey
# 0     335984      Delhi  2008-04-19     MF Maharoof  \
# 1     335985     Mumbai  2008-04-20      MV Boucher
# 2     335986    Kolkata  2008-04-20       DJ Hussey
# 3     335987     Jaipur  2008-04-21       SR Watson
# 4     335988  Hyderabad  2008-04-22        V Sehwag
# ..       ...        ...         ...             ...
# 809  1216547      Dubai  2020-09-28  AB de Villiers
# 810  1237177      Dubai  2020-11-05       JJ Bumrah
# 811  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 812  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 813  1237181      Dubai  2020-11-10        TA Boult
#
#     Punjab Cricket Association Stadium, Mohali  0
# 0                             Feroz Shah Kotla  0  \
# 1                             Wankhede Stadium  0
# 2                                 Eden Gardens  0
# 3                       Sawai Mansingh Stadium  0
# 4    Rajiv Gandhi International Stadium, Uppal  0
# ...

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv", nrows = 5)
df
# gether first 5 rows
# Out:
#        id        city        date player_of_match
# 0  335982   Bangalore  2008-04-18     BB McCullum  \
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue
# 0                       M Chinnaswamy Stadium              0  \
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2
# 0  Royal Challengers Bangalore        Kolkata Knight Riders  \
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %% [markdown]
# # 9. Encoding parameter

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv", encoding = "latin-1")
# df

# %% [markdown]
# # 10. Skip bad lines

# %%
# df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv", warn_bad_lines = False)
#

# %% [markdown]
# # 11.dtypes parameter

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
# df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv" , dtype = {"result_margin":int}).info()
df
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore  2008-04-18     BB McCullum  \
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # 12. Handling Dates

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv",parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# # 13. Convertors

# %%
]: pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename})
# Out:
#   Cell In[16], line 1
#     ]: pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename})
#     ^
# SyntaxError: unmatched ']'

# %% [markdown]
# # 14. na_values parameter

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv", na_values = ["winner"])
# for not available data handling
df
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore  2008-04-18     BB McCullum  \
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # 15. Loading a huge dataset in chunks

# %%
df = pd.read_csv("C:/Users/patan/Downloads/IPL Matches 2008-2020.csv",chunksize=5000)
for chunks in df:
    print(chunks)
# Out:
#           id        city        date player_of_match
# 0     335982   Bangalore  2008-04-18     BB McCullum  \
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue
# 0                         M Chinnaswamy Stadium              0  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # 16. Working with JSON(Js Object Notation) /SQL

# %%
df = pd.read_json("C:/Users/patan/Downloads/train.json")
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# # 17. Working with SQL

# %%
# from mysql.connector import (connection)

# %%
# conn = mysql.connector.connect(host='localhost',user='root',password='',database='w')

# %%
# df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
df

# %% [markdown]
# #   17. Using API

# %%
import requests as r
response = r.get('https://www.omdbapi.com/?i=tt3896198&apikey=98d5d7d7')
response.json()
pd.DataFrame(response.json()).head(2)[["Title", "Year","Runtime","imdbRating","BoxOffice"]]
# Out:
#                             Title  Year  Runtime imdbRating     BoxOffice
# 0  Guardians of the Galaxy Vol. 2  2017  136 min        7.6  $389,813,101
# 1  Guardians of the Galaxy Vol. 2  2017  136 min        7.6  $389,813,101

# %% [markdown]
# # 18.Using
